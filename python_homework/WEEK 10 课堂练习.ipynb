# %%
from selenium import webdriver
from pyquery import PyQuery as pq


dr = webdriver.Chrome()
dr.get("http://www.baidu.com")

# %%
dir(dr)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_file_detector',
#  '_is_remote',
#  '_mobile',
#  '_switch_to',
#  '_unwrap_value',
#  '_web_element_cls',
#  '_wrap_value',
#  'add_cookie',
#  'application_cache',
#  'back',
#  'capabilities',
#  'close',
#  'command_executor',
#  'create_options',
#  'create_web_element',
#  'current_url',
#  'current_window_handle',
#  'delete_all_cookies',
#  'delete_cookie',
#  'desired_capabilities',
#  'error_handler',
#  'execute',
#  'execute_async_script',
#  'execute_cdp_cmd',
#  'execute_script',
#  'file_detector',
# ...

# %%
dr.find_elements_by_id('kw')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="18112076c0df621d62f7c903d75949b4", element="bcdb4ac5-261a-44a0-a00a-1d66155c7dd9")>]

# %%
dr.find_element_by_id('kw').send_keys('费凡')

# %%
dr.find_element_by_id('su').click()

# %%
html=dr.page_source

# %%
print(html)
# Out:
# <html><head>
#
# ...

# %%
doc=pq(html)
lst=doc('div#content_left')

# %%
lst
# Out:
# [<div#content_left>]

# %%
pq(lst[0]).find('h3').text()
# Out:
# '费凡_百度百科 费凡 简历_安永大中华地区生命科学行业 主管合伙人费凡 受邀参会... 摄影师费凡的微博_微博 费凡_百度图片 费凡 有多少费凡,费凡同名同姓-人人网 校内 「费凡」安永中国合伙人简介_联系方式_创业感悟_新闻-投融界 费凡吧-百度贴吧 费凡_上海慧氏企业发展有限公司_费凡个人信用报告_相关联企业信息... 费凡姓名测试82分,费凡五行土水,费凡三才五格吉凶,费凡笔画查询 摄影师费凡的主页 - 站酷 (ZCOOL)'

# %%
pq(lst[0]).find('.c-row').text()
# Out:
# '籍贯：江苏南通\n费凡，男，江苏南通人，因参加2010年4月18日的江苏卫视《非诚勿扰》节目而被大家熟知。节目中，节俭内敛的费凡心仪女嘉宾谢佳，为其吟诗，赠送礼物，但最终还是...\n简介 相亲 写给女嘉宾的诗\nhttps://baike.baidu.com/ 2017年11月23日\xa0-\xa0费凡 是谁?活动家提供费凡 简历,费凡 演讲及出席会议历程(更新于:2017年11月24日)。费凡 ,安永大中华地区生命科学行业 主管合伙人,近期共出席会议1场,作为...\nhttps://www.huodongjia.com/gue...\n-\xa0百度快照 摄影师费凡,知名摄影师,合作《ELLE》《瑞丽》《昕薇》《小资风尚》等。摄影师费凡的微博主页、个人资料、相册,上海face文化传播有限公司。新浪微博,随时随地分享...\n.source-icon { vertical-align: middle; width: 14px; height: 14px; border: 1px solid #eee; border-radius: 100%; margin-right: 5px; margin-top: -3px; }\n微博\n-\xa0百度快照 摄影师费凡 上海| 摄影师中国摄影师协会CPA理事 美国摄影师协会PPA会员 2015年新浪微博十佳时尚摄影师分享 分享至微信朋友圈 分享给微信好友 新浪微博 QQ好友 ...\nhttps://feifanphoto.zcool.com.cn/\n-\xa0百度快照'

# %%
pq(lst[0]).find('a').text()
# Out:
# '费凡_百度百科 简介 相亲 写给女嘉宾的诗  费凡 简历_安永大中华地区生命科学行业 主管合伙人费凡 受邀参会...  https://www.huodongjia.com/gue...  百度快照 摄影师费凡的微博_微博  .source-icon { vertical-align: middle; width: 14px; height: 14px; border: 1px solid #eee; border-radius: 100%; margin-right: 5px; margin-top: -3px; }\n微博  百度快照 费凡是我的微博_微博 费凡平的微博_微博 更多同站结果>> 费凡_百度图片       查看全部5,633张图片 费凡 有多少费凡,费凡同名同姓-人人网 校内 .source-icon { vertical-align: middle; width: 14px; height: 14px; border: 1px solid #eee; border-radius: 100%; margin-right: 5px; margin-top: -3px; }\n人人网  百度快照 「费凡」安永中国合伙人简介_联系方式_创业感悟_新闻-投融界 https://www.trjcn.com/ceo/282....  百度快照 费凡吧-百度贴吧 .source-icon { vertical-align: middle; width: 14px; height: 14px; border: 1px solid #eee; border-radius: 100%; margin-right: 5px; margin-top: -3px; }\n百度贴吧  百度快照 费凡_上海慧氏企业发展有限公司_费凡个人信用报告_相关联企业信息... .source-icon { vertical-align: middle; width: 14px; height: 14px; border: 1px solid #eee; border-radius: 100%; margin-right: 5px; margin-top: -3px; }\n天眼查  百度快照 费凡姓名测试82分,费凡五行土水,费凡三才五格吉凶,费凡笔画查询 www.name321
# ...
